# %%
import random

# %%
num_students = 450
num_universities = 8
min_num_groups = 1
min_group_size = 20
max_group_size = 30
max_num_groups = 5    

students = list(range(num_students))
universities = list(range(num_universities))

# %%
# Генерация меток
student_labels = {
    'is_target': [0] * num_students,
    'is_contract': [0] * num_students,
    'debts': [],
    'rating': []}

# Генерация меток целевых студентов
num_target_students = int(0.05 * num_students)
target_students = random.sample(students, num_target_students)

for target in target_students:
    student_labels['is_target'][target] = 1

# Генерация меток контрактников
num_contract_students = int(0.3 * num_students)
contract_students = random.sample(students, num_contract_students)

for contract in contract_students:
    student_labels['is_contract'][contract] = 1

# Генерация академических задолженностей
def generate_debts():
    return random.choices(range(8), weights=[10, 5, 3, 3, 2, 2, 1, 1], k=1)[0]

student_labels['debts'] = [generate_debts() for _ in students]

# Генерация баллов рейтинга
student_labels['rating'] = [random.randint(0, 500) for _ in students]

# %%
for i in range(num_students):
    print(f"Студент {i}: Целевой - {student_labels['is_target'][i]}, "
          f"Контрактник - {student_labels['is_contract'][i]}, "
          f"Долги - {student_labels['debts'][i]}, "
          f"БРС - {student_labels['rating'][i]}")
# Out:
# Студент 0: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 392
# Студент 1: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 127
# Студент 2: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 416
# Студент 3: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 103
# Студент 4: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 227
# Студент 5: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 22
# Студент 6: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 229
# Студент 7: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 0
# Студент 8: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 93
# Студент 9: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 105
# Студент 10: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 267
# Студент 11: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 34
# Студент 12: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 55
# Студент 13: Целевой - 0, Контрактник - 0, Долги - 7, БРС - 255
# Студент 14: Целевой - 0, Контрактник - 1, Долги - 4, БРС - 30
# Студент 15: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 151
# Студент 16: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 104
# Студент 17: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 50
# Студент 18: Целевой - 0, Контрактник - 1, Долги - 4, БРС - 181
# Студент 19: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 340
# Студент 20: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 472
# Студент 21: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 67
# Студент 22: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 329
# Студент 23: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 42
# Студент 24: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 122
# Студент 25: Целевой - 0, Контрактник - 1, Долги - 2, БРС - 13
# Студент 26: Целевой - 0, Контрактник - 0, Долги - 7, БРС - 347
# Студент 27: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 225
# Студент 28: Целевой - 0, Контрактник - 1, Долги - 4, БРС - 53
# Студент 29: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 437
# Студент 30: Целевой - 0, Контрактник - 1, Долги - 4, БРС - 141
# Студент 31: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 271
# Студент 32: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 275
# Студент 33: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 374
# Студент 34: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 169
# Студент 35: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 257
# Студент 36: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 307
# Студент 37: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 459
# Студент 38: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 286
# Студент 39: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 69
# Студент 40: Целевой - 0, Контрактник - 0, Долги - 7, БРС - 234
# Студент 41: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 419
# Студент 42: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 225
# Студент 43: Целевой - 0, Контрактник - 1, Долги - 2, БРС - 18
# Студент 44: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 1
# Студент 45: Целевой - 0, Контрактник - 0, Долги - 6, БРС - 461
# Студент 46: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 166
# Студент 47: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 234
# Студент 48: Целевой - 1, Контрактник - 0, Долги - 3, БРС - 495
# Студент 49: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 37
# Студент 50: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 247
# Студент 51: Целевой - 0, Контрактник - 0, Долги - 7, БРС - 484
# Студент 52: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 445
# Студент 53: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 88
# Студент 54: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 391
# Студент 55: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 342
# Студент 56: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 238
# Студент 57: Целевой - 0, Контрактник - 1, Долги - 2, БРС - 408
# Студент 58: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 210
# Студент 59: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 24
# Студент 60: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 95
# Студент 61: Целевой - 0, Контрактник - 1, Долги - 2, БРС - 390
# Студент 62: Целевой - 1, Контрактник - 0, Долги - 0, БРС - 438
# Студент 63: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 49
# Студент 64: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 3
# Студент 65: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 166
# Студент 66: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 280
# Студент 67: Целевой - 0, Контрактник - 1, Долги - 7, БРС - 76
# Студент 68: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 204
# Студент 69: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 448
# Студент 70: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 271
# Студент 71: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 474
# Студент 72: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 245
# Студент 73: Целевой - 1, Контрактник - 1, Долги - 7, БРС - 289
# Студент 74: Целевой - 0, Контрактник - 1, Долги - 4, БРС - 121
# Студент 75: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 30
# Студент 76: Целевой - 0, Контрактник - 0, Долги - 6, БРС - 203
# Студент 77: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 384
# Студент 78: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 291
# Студент 79: Целевой - 0, Контрактник - 1, Долги - 5, БРС - 94
# Студент 80: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 58
# Студент 81: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 315
# Студент 82: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 28
# Студент 83: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 364
# Студент 84: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 367
# Студент 85: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 439
# Студент 86: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 210
# Студент 87: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 351
# Студент 88: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 401
# Студент 89: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 435
# Студент 90: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 196
# Студент 91: Целевой - 0, Контрактник - 1, Долги - 3, БРС - 121
# Студент 92: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 436
# Студент 93: Целевой - 0, Контрактник - 1, Долги - 5, БРС - 126
# Студент 94: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 290
# Студент 95: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 129
# Студент 96: Целевой - 0, Контрактник - 1, Долги - 4, БРС - 377
# Студент 97: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 112
# Студент 98: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 186
# Студент 99: Целевой - 0, Контрактник - 1, Долги - 4, БРС - 410
# Студент 100: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 49
# Студент 101: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 428
# Студент 102: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 238
# Студент 103: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 291
# Студент 104: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 168
# Студент 105: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 169
# Студент 106: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 316
# Студент 107: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 21
# Студент 108: Целевой - 0, Контрактник - 1, Долги - 5, БРС - 37
# Студент 109: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 294
# Студент 110: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 476
# Студент 111: Целевой - 0, Контрактник - 1, Долги - 2, БРС - 52
# Студент 112: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 387
# Студент 113: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 92
# Студент 114: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 33
# Студент 115: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 11
# Студент 116: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 412
# Студент 117: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 375
# Студент 118: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 41
# Студент 119: Целевой - 0, Контрактник - 0, Долги - 6, БРС - 250
# Студент 120: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 72
# Студент 121: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 299
# Студент 122: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 79
# Студент 123: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 428
# Студент 124: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 280
# Студент 125: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 51
# Студент 126: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 379
# Студент 127: Целевой - 0, Контрактник - 1, Долги - 4, БРС - 491
# Студент 128: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 294
# Студент 129: Целевой - 1, Контрактник - 1, Долги - 0, БРС - 49
# Студент 130: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 163
# Студент 131: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 114
# Студент 132: Целевой - 0, Контрактник - 1, Долги - 2, БРС - 334
# Студент 133: Целевой - 1, Контрактник - 0, Долги - 4, БРС - 74
# Студент 134: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 473
# Студент 135: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 259
# Студент 136: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 402
# Студент 137: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 235
# Студент 138: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 434
# Студент 139: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 378
# Студент 140: Целевой - 1, Контрактник - 0, Долги - 1, БРС - 175
# Студент 141: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 116
# Студент 142: Целевой - 0, Контрактник - 1, Долги - 4, БРС - 267
# Студент 143: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 11
# Студент 144: Целевой - 0, Контрактник - 1, Долги - 2, БРС - 298
# Студент 145: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 296
# Студент 146: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 490
# Студент 147: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 96
# Студент 148: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 294
# Студент 149: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 345
# Студент 150: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 377
# Студент 151: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 415
# Студент 152: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 235
# Студент 153: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 473
# Студент 154: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 21
# Студент 155: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 220
# Студент 156: Целевой - 1, Контрактник - 0, Долги - 0, БРС - 234
# Студент 157: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 364
# Студент 158: Целевой - 1, Контрактник - 1, Долги - 1, БРС - 167
# Студент 159: Целевой - 0, Контрактник - 1, Долги - 3, БРС - 255
# Студент 160: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 9
# Студент 161: Целевой - 0, Контрактник - 1, Долги - 7, БРС - 205
# Студент 162: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 210
# Студент 163: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 485
# Студент 164: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 431
# Студент 165: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 393
# Студент 166: Целевой - 0, Контрактник - 1, Долги - 2, БРС - 34
# Студент 167: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 65
# Студент 168: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 406
# Студент 169: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 253
# Студент 170: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 242
# Студент 171: Целевой - 0, Контрактник - 0, Долги - 6, БРС - 299
# Студент 172: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 121
# Студент 173: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 11
# Студент 174: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 347
# Студент 175: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 84
# Студент 176: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 486
# Студент 177: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 408
# Студент 178: Целевой - 0, Контрактник - 1, Долги - 3, БРС - 437
# Студент 179: Целевой - 0, Контрактник - 1, Долги - 4, БРС - 497
# Студент 180: Целевой - 0, Контрактник - 1, Долги - 3, БРС - 314
# Студент 181: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 136
# Студент 182: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 374
# Студент 183: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 78
# Студент 184: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 226
# Студент 185: Целевой - 0, Контрактник - 0, Долги - 7, БРС - 31
# Студент 186: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 417
# Студент 187: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 110
# Студент 188: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 92
# Студент 189: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 266
# Студент 190: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 410
# Студент 191: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 170
# Студент 192: Целевой - 0, Контрактник - 0, Долги - 6, БРС - 70
# Студент 193: Целевой - 0, Контрактник - 0, Долги - 7, БРС - 278
# Студент 194: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 342
# Студент 195: Целевой - 1, Контрактник - 0, Долги - 0, БРС - 214
# Студент 196: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 430
# Студент 197: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 127
# Студент 198: Целевой - 0, Контрактник - 0, Долги - 6, БРС - 45
# Студент 199: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 61
# Студент 200: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 285
# Студент 201: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 18
# Студент 202: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 82
# Студент 203: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 279
# Студент 204: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 37
# Студент 205: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 447
# Студент 206: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 437
# Студент 207: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 455
# Студент 208: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 61
# Студент 209: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 452
# Студент 210: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 411
# Студент 211: Целевой - 1, Контрактник - 1, Долги - 3, БРС - 177
# Студент 212: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 341
# Студент 213: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 68
# Студент 214: Целевой - 0, Контрактник - 1, Долги - 4, БРС - 254
# Студент 215: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 166
# Студент 216: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 399
# Студент 217: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 194
# Студент 218: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 75
# Студент 219: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 271
# Студент 220: Целевой - 0, Контрактник - 1, Долги - 6, БРС - 306
# Студент 221: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 362
# Студент 222: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 388
# Студент 223: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 363
# Студент 224: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 372
# Студент 225: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 497
# Студент 226: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 61
# Студент 227: Целевой - 0, Контрактник - 0, Долги - 6, БРС - 250
# Студент 228: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 154
# Студент 229: Целевой - 0, Контрактник - 1, Долги - 5, БРС - 66
# Студент 230: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 494
# Студент 231: Целевой - 0, Контрактник - 1, Долги - 7, БРС - 338
# Студент 232: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 95
# Студент 233: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 433
# Студент 234: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 279
# Студент 235: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 406
# Студент 236: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 29
# Студент 237: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 383
# Студент 238: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 464
# Студент 239: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 358
# Студент 240: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 283
# Студент 241: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 173
# Студент 242: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 424
# Студент 243: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 299
# Студент 244: Целевой - 0, Контрактник - 0, Долги - 7, БРС - 393
# Студент 245: Целевой - 0, Контрактник - 1, Долги - 6, БРС - 417
# Студент 246: Целевой - 0, Контрактник - 0, Долги - 7, БРС - 411
# Студент 247: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 266
# Студент 248: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 67
# Студент 249: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 404
# Студент 250: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 439
# Студент 251: Целевой - 0, Контрактник - 0, Долги - 6, БРС - 84
# Студент 252: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 353
# Студент 253: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 94
# Студент 254: Целевой - 0, Контрактник - 1, Долги - 3, БРС - 267
# Студент 255: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 263
# Студент 256: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 393
# Студент 257: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 440
# Студент 258: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 17
# Студент 259: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 354
# Студент 260: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 421
# Студент 261: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 475
# Студент 262: Целевой - 0, Контрактник - 1, Долги - 4, БРС - 257
# Студент 263: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 294
# Студент 264: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 119
# Студент 265: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 384
# Студент 266: Целевой - 0, Контрактник - 1, Долги - 2, БРС - 461
# Студент 267: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 369
# Студент 268: Целевой - 0, Контрактник - 1, Долги - 2, БРС - 177
# Студент 269: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 388
# Студент 270: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 424
# Студент 271: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 111
# Студент 272: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 91
# Студент 273: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 252
# Студент 274: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 374
# Студент 275: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 92
# Студент 276: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 374
# Студент 277: Целевой - 0, Контрактник - 1, Долги - 5, БРС - 318
# Студент 278: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 396
# Студент 279: Целевой - 0, Контрактник - 1, Долги - 2, БРС - 29
# Студент 280: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 183
# Студент 281: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 321
# Студент 282: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 24
# Студент 283: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 210
# Студент 284: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 339
# Студент 285: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 342
# Студент 286: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 466
# Студент 287: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 75
# Студент 288: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 227
# Студент 289: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 499
# Студент 290: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 91
# Студент 291: Целевой - 0, Контрактник - 1, Долги - 3, БРС - 452
# Студент 292: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 359
# Студент 293: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 437
# Студент 294: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 139
# Студент 295: Целевой - 1, Контрактник - 0, Долги - 0, БРС - 296
# Студент 296: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 178
# Студент 297: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 17
# Студент 298: Целевой - 0, Контрактник - 1, Долги - 5, БРС - 30
# Студент 299: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 167
# Студент 300: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 72
# Студент 301: Целевой - 0, Контрактник - 1, Долги - 4, БРС - 325
# Студент 302: Целевой - 0, Контрактник - 0, Долги - 7, БРС - 156
# Студент 303: Целевой - 0, Контрактник - 1, Долги - 5, БРС - 31
# Студент 304: Целевой - 0, Контрактник - 1, Долги - 4, БРС - 54
# Студент 305: Целевой - 0, Контрактник - 1, Долги - 7, БРС - 465
# Студент 306: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 195
# Студент 307: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 115
# Студент 308: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 81
# Студент 309: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 337
# Студент 310: Целевой - 1, Контрактник - 0, Долги - 5, БРС - 159
# Студент 311: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 6
# Студент 312: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 36
# Студент 313: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 0
# Студент 314: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 5
# Студент 315: Целевой - 1, Контрактник - 0, Долги - 4, БРС - 303
# Студент 316: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 167
# Студент 317: Целевой - 1, Контрактник - 0, Долги - 0, БРС - 499
# Студент 318: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 483
# Студент 319: Целевой - 0, Контрактник - 1, Долги - 5, БРС - 262
# Студент 320: Целевой - 1, Контрактник - 0, Долги - 0, БРС - 431
# Студент 321: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 438
# Студент 322: Целевой - 0, Контрактник - 0, Долги - 7, БРС - 211
# Студент 323: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 259
# Студент 324: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 377
# Студент 325: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 411
# Студент 326: Целевой - 0, Контрактник - 0, Долги - 6, БРС - 438
# Студент 327: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 232
# Студент 328: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 384
# Студент 329: Целевой - 1, Контрактник - 0, Долги - 3, БРС - 348
# Студент 330: Целевой - 1, Контрактник - 0, Долги - 1, БРС - 177
# Студент 331: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 250
# Студент 332: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 370
# Студент 333: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 274
# Студент 334: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 98
# Студент 335: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 317
# Студент 336: Целевой - 0, Контрактник - 1, Долги - 6, БРС - 46
# Студент 337: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 428
# Студент 338: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 91
# Студент 339: Целевой - 1, Контрактник - 0, Долги - 1, БРС - 239
# Студент 340: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 228
# Студент 341: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 492
# Студент 342: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 127
# Студент 343: Целевой - 1, Контрактник - 0, Долги - 0, БРС - 247
# Студент 344: Целевой - 0, Контрактник - 0, Долги - 6, БРС - 85
# Студент 345: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 413
# Студент 346: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 107
# Студент 347: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 254
# Студент 348: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 235
# Студент 349: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 358
# Студент 350: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 40
# Студент 351: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 206
# Студент 352: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 478
# Студент 353: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 364
# Студент 354: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 63
# Студент 355: Целевой - 0, Контрактник - 1, Долги - 4, БРС - 56
# Студент 356: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 3
# Студент 357: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 419
# Студент 358: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 292
# Студент 359: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 177
# Студент 360: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 289
# Студент 361: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 327
# Студент 362: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 113
# Студент 363: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 35
# Студент 364: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 12
# Студент 365: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 491
# Студент 366: Целевой - 0, Контрактник - 1, Долги - 6, БРС - 141
# Студент 367: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 291
# Студент 368: Целевой - 0, Контрактник - 1, Долги - 6, БРС - 351
# Студент 369: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 275
# Студент 370: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 364
# Студент 371: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 211
# Студент 372: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 30
# Студент 373: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 164
# Студент 374: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 148
# Студент 375: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 257
# Студент 376: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 464
# Студент 377: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 423
# Студент 378: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 394
# Студент 379: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 486
# Студент 380: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 346
# Студент 381: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 160
# Студент 382: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 306
# Студент 383: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 384
# Студент 384: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 227
# Студент 385: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 233
# Студент 386: Целевой - 0, Контрактник - 1, Долги - 4, БРС - 3
# Студент 387: Целевой - 1, Контрактник - 1, Долги - 3, БРС - 454
# Студент 388: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 111
# Студент 389: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 261
# Студент 390: Целевой - 0, Контрактник - 1, Долги - 3, БРС - 388
# Студент 391: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 421
# Студент 392: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 444
# Студент 393: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 29
# Студент 394: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 165
# Студент 395: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 462
# Студент 396: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 407
# Студент 397: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 354
# Студент 398: Целевой - 1, Контрактник - 1, Долги - 5, БРС - 276
# Студент 399: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 184
# Студент 400: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 394
# Студент 401: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 355
# Студент 402: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 426
# Студент 403: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 26
# Студент 404: Целевой - 0, Контрактник - 1, Долги - 2, БРС - 319
# Студент 405: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 37
# Студент 406: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 3
# Студент 407: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 405
# Студент 408: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 189
# Студент 409: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 387
# Студент 410: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 408
# Студент 411: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 48
# Студент 412: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 414
# Студент 413: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 143
# Студент 414: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 175
# Студент 415: Целевой - 0, Контрактник - 1, Долги - 6, БРС - 226
# Студент 416: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 184
# Студент 417: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 160
# Студент 418: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 250
# Студент 419: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 498
# Студент 420: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 485
# Студент 421: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 54
# Студент 422: Целевой - 0, Контрактник - 0, Долги - 7, БРС - 176
# Студент 423: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 201
# Студент 424: Целевой - 0, Контрактник - 0, Долги - 6, БРС - 121
# Студент 425: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 274
# Студент 426: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 9
# Студент 427: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 397
# Студент 428: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 214
# Студент 429: Целевой - 0, Контрактник - 1, Долги - 6, БРС - 451
# Студент 430: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 63
# Студент 431: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 465
# Студент 432: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 53
# Студент 433: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 290
# Студент 434: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 9
# Студент 435: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 92
# Студент 436: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 102
# Студент 437: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 374
# Студент 438: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 286
# Студент 439: Целевой - 0, Контрактник - 1, Долги - 2, БРС - 367
# Студент 440: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 228
# Студент 441: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 18
# Студент 442: Целевой - 0, Контрактник - 0, Долги - 6, БРС - 340
# Студент 443: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 176
# Студент 444: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 212
# Студент 445: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 415
# Студент 446: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 484
# Студент 447: Целевой - 0, Контрактник - 0, Долги - 7, БРС - 207
# Студент 448: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 369
# Студент 449: Целевой - 1, Контрактник - 0, Долги - 2, БРС - 331

# %%
# Генерация предпочтений студентов
preferences_s = {}
for student in students:
    if student_labels['debts'][student] > 5:
        preferences_s[student] = []  # Равнодушие к университетам, пустой список
    else:
        preferences_s[student] = random.sample(universities, k=num_universities)  # Выбор университетов

# Генерация предпочтений университетов
preferences_u = {}
for uni in universities:
    target_students_sorted = sorted(
        [s for s in students if student_labels['is_target'][s] == 1],
        key=lambda s: -student_labels['rating'][s]
    )

    other_students = sorted(
        [s for s in students if student_labels['is_target'][s] == 0 and student_labels['debts'][s] <= 5],
        key=lambda s: (-student_labels['rating'][s], -student_labels['is_contract'][s])
    )

    debt_students = sorted(
        [s for s in students if student_labels['debts'][s] > 5],
        key=lambda s: -student_labels['rating'][s]
    )

    # Формируем полные предпочтения для университета
    preferences_u[uni] = target_students_sorted + other_students + debt_students


# Сформируем квоты для университетов
quotas = [max_group_size * max_num_groups for _ in range(num_universities)]

# %%
# Подсчет студентов, которые поставили университет первым приоритетом
priority_count = {uni: 0 for uni in universities}
target_priority_count = {uni: 0 for uni in universities}

for student in students:
    if preferences_s[student]:  # Проверяем, есть ли предпочтения
        first_preference = preferences_s[student][0]
        priority_count[first_preference] += 1  # Увеличиваем счетчик для данного университета
        # Учитываем только целевых студентов, которые поставили этот университет первым
        if student_labels['is_target'][student] == 1 and first_preference == preferences_s[student][0]:
            target_priority_count[first_preference] += 1  # Увеличиваем счетчик целевых студентов

# Определение обязательных университетов
mandatory_universities = [
    uni for uni in universities 
    if target_priority_count[uni] > 4 or priority_count[uni] > 60
]

# Количество обязательных университетов
num_mandatory_universities = len(mandatory_universities)

# Объем резерва
reserve_size = num_mandatory_universities * min_num_groups * min_students_in_group
reserve_students = []

# Список студентов без предпочтений
students_without_preferences = []
for student in students:
    if not preferences_s[student]:
        students_without_preferences.append(student)

# Список оставшихся нецелевых студентов
remaining_students = []
for student in students:
    if student_labels['is_target'][student] == 0:
        remaining_students.append(student)
        
# Заполнение резерва студентами без предпочтений
students_without_preferences_sorted = sorted(
    students_without_preferences, 
    key=lambda s: student_labels['rating'][s]
)

for student in reversed(students_without_preferences_sorted):
    if len(reserve_students) < reserve_size:
        reserve_students.append(student)
    else:
        break

# Заполнение резерва оставшимися нецелевыми студентами
remaining_students_sorted = sorted(
    remaining_students,
    key=lambda s: student_labels['rating'][s]
)

for student in reversed(remaining_students_sorted):
    if len(reserve_students) < reserve_size:
        reserve_students.append(student)
    else:
        break

# Вывод результатов
for uni in universities:
    print(f"Университет {uni}: Студенты, поставившие первым приоритетом: {priority_count[uni]}, "
          f"целевиков: {target_priority_count[uni]}")

print(f"Размер резерва студентов: {len(reserve_students)}")
print(f"Резерв студентов: {reserve_students}")
# Out:
# Университет 0: Студенты, поставившие первым приоритетом: 48, целевиков: 2
# Университет 1: Студенты, поставившие первым приоритетом: 44, целевиков: 3
# Университет 2: Студенты, поставившие первым приоритетом: 52, целевиков: 1
# Университет 3: Студенты, поставившие первым приоритетом: 64, целевиков: 4
# Университет 4: Студенты, поставившие первым приоритетом: 51, целевиков: 4
# Университет 5: Студенты, поставившие первым приоритетом: 46, целевиков: 2
# Университет 6: Студенты, поставившие первым приоритетом: 54, целевиков: 3
# Университет 7: Студенты, поставившие первым приоритетом: 55, целевиков: 2
# Размер резерва студентов: 20
# Резерв студентов: [51, 305, 45, 429, 326, 245, 246, 244, 368, 26, 442, 231, 220, 171, 73, 193, 13, 227, 119, 40]

# %%
# Реализация первого шага распределения
university_matches = {uni: [] for uni in range(num_universities)}  # Сопоставления университетов
student_matches = {student: None for student in range(num_students)}  # Сопоставления студентов

# Распределение целевых студентов по университетам
for student in students:
    if student_labels['is_target'][student] == 1:  # Проверяем, является ли студент целевым
        if preferences_s[student]:  # Проверяем, есть ли предпочтения
            first_preference = preferences_s[student][0]  # Получаем первый приоритет
            university_matches[first_preference].append(student)  # Добавляем студента в университет
            student_matches[student] = first_preference  # Помечаем, в какой университет распределен студент

# Создание списка оставшихся студентов
remaining_students_after_distribution = []
for student in students:
    if student_matches[student] is None:
        remaining_students_after_distribution.append(student)

# Вывод результатов
for uni, matched_students in university_matches.items():
    print(f"Университет {uni}: Студенты - {matched_students}")
# Out:
# Университет 0: Студенты - [329, 449]
# Университет 1: Студенты - [295, 310, 330]
# Университет 2: Студенты - [195]
# Университет 3: Студенты - [140, 317, 339, 398]
# Университет 4: Студенты - [156, 158, 343, 387]
# Университет 5: Студенты - [129, 211]
# Университет 6: Студенты - [62, 133, 320]
# Университет 7: Студенты - [48, 315]

# %%
len(remaining_students_after_distribution)
# Out:
# 429

# %%
mandatory_universities
# Out:
# [3]

# %%
def gale_shapley(num_students, num_universities, quotas, preferences_s, preferences_u, university_matches, student_matches, mandatory_universities, reserve_students):
    # Инициализация
    reserve_set = set(reserve_students)  # Студенты в резерве
    # Убираем студентов из резерва из remaining_students_after_distribution
    free_students = [s for s in remaining_students_after_distribution if s not in reserve_set]  
    proposed = {student: 0 for student in range(num_students)}  # Счетчик предложений

    while free_students:
        # Вытаскиваем свободного студента
        student = free_students[0]
        student_pref = preferences_s[student]

        # Находим наиболее предпочтительный университет, которому студент еще не делал предложение
        uni_index = proposed[student]

        if uni_index < len(student_pref):  # Здесь используем длину предпочтений, чтобы не сломаться на студентах с пустыми списками
            uni = student_pref[uni_index]
            proposed[student] += 1

              # Если университет свободен, совмещаем
            if len(university_matches[uni]) < quotas[uni]:
                university_matches[uni].append(student)
                university_matches[uni].sort(key=preferences_u[uni].index)
                student_matches[student] = uni
                free_students.pop(0)
                
                # Проверяем, связан ли университет с обязательным профилем и обрабатываем резерв
                if uni in mandatory_universities and reserve_students:
                    student_from_reserve = reserve_students.pop(0)  # Берем первого студента из резерва
                    free_students.append(student_from_reserve)  # Добавляем студента в список свободных
            else:
                # Если университет занят, проверяем, хочет ли он заменить текущего худшего студента
                current_student = university_matches[uni][-1]
                uni_pref = preferences_u[uni]

                if uni_pref.index(student) < uni_pref.index(current_student):
                    university_matches[uni].pop()
                    university_matches[uni].append(student)
                    university_matches[uni].sort(key=uni_pref.index)
                    student_matches[student] = uni
                    student_matches[current_student] = None
                    free_students.pop(0)
                    free_students.append(current_student)
                    
                    # Проверяем, связан ли университет с обязательным профилем и обрабатываем резерв
                    if uni in mandatory_universities and reserve_students:
                        student_from_reserve = reserve_students.pop(0)  # Берем первого студента из резерва
                        free_students.append(student_from_reserve)  # Добавляем студента во свободные списки
        else:
            # Если студент сделал все предложения, он становится несопоставленным
            free_students.pop(0)

    # Список студентов с пустыми предпочтениями
    students_with_no_preferences = [s for s in range(num_students) if len(preferences_s[s]) == 0]
    # Основной цикл распределения завершен

    # Теперь распределяем студентов с пустыми предпочтениями случайным образом
    for student in students_with_no_preferences:
        available_universities = [uni for uni in range(num_universities) if len(university_matches[uni]) < quotas[uni]]
        if available_universities:  # Если есть доступные университеты
            uni = random.choice(available_universities)  # Случайный университет
            university_matches[uni].append(student)  # Записываем студента в университет
            student_matches[student] = uni  # Обновляем сопоставление студента
    
    # Список несопоставленных студентов
    unmatched_students = [s for s in range(num_students) if student_matches[s] is None]

    return university_matches, student_matches, unmatched_students

# %%
university_matches, student_matches, unmatched_students = gale_shapley(
    num_students, num_universities, quotas, preferences_s, preferences_u, university_matches, student_matches, mandatory_universities, reserve_students
)

# %%
for uni, matched_students in university_matches.items():
    print(f"Профиль {uni}: Студенты - {matched_students}")
    print(f"Всего на профиле {uni} {len(matched_students)} студентов")
print("Незачисленные студенты:")
print(unmatched_students)
# Out:
# Профиль 0: Студенты - [329, 449, 179, 230, 146, 376, 37, 207, 69, 29, 89, 101, 410, 222, 77, 96, 150, 324, 401, 252, 284, 404, 106, 145, 103, 66, 319, 375, 214, 283, 217, 268, 104, 197, 24, 388, 253, 113, 430, 199, 355, 125, 118, 204, 405, 403, 154, 44, 193, 251, 366, 422, 447]
# Всего на профиле 0 53 студентов
# Профиль 1: Студенты - [295, 330, 310, 225, 420, 286, 209, 138, 196, 402, 391, 357, 412, 116, 249, 139, 370, 309, 361, 277, 36, 389, 347, 50, 288, 428, 162, 90, 130, 381, 15, 97, 271, 232, 60, 202, 308, 39, 208, 350, 108, 298, 75, 282, 13, 51, 227, 305, 326, 368, 424]
# Всего на профиле 1 51 студентов
# Профиль 2: Студенты - [195, 341, 127, 261, 431, 164, 337, 151, 190, 168, 378, 400, 256, 328, 383, 274, 267, 83, 157, 353, 87, 174, 132, 335, 243, 78, 367, 240, 203, 32, 255, 169, 348, 440, 4, 399, 416, 443, 299, 316, 215, 374, 413, 74, 307, 131, 53, 218, 354, 114, 59, 314, 73, 246, 429]
# Всего на профиле 2 55 студентов
# Профиль 3: Студенты - [317, 398, 339, 140, 419, 379, 318, 110, 134, 392, 257, 178, 206, 242, 186, 345, 210, 325, 99, 57, 235, 390, 182, 84, 397, 259, 81, 200, 124, 219, 56, 102, 184, 444, 423, 18, 359, 34, 65, 373, 417, 30, 181, 95, 342, 93, 187, 346, 275, 290, 338, 100, 23, 312, 166, 14, 279, 393, 107, 297, 115, 356, 7, 313, 40, 192, 231, 336]
# Всего на профиле 3 68 студентов
# Профиль 4: Студенты - [387, 343, 156, 158, 163, 71, 238, 205, 52, 293, 92, 233, 88, 269, 112, 126, 332, 221, 349, 285, 19, 281, 109, 148, 358, 433, 38, 438, 418, 47, 384, 351, 172, 16, 3, 188, 272, 287, 120, 167, 80, 304, 111, 363, 236, 82, 43, 201, 25, 173, 64, 161, 220, 322]
# Всего на профиле 4 54 студентов
# Профиль 5: Студенты - [211, 129, 446, 153, 321, 41, 445, 165, 54, 265, 237, 224, 439, 380, 149, 55, 22, 180, 382, 144, 263, 94, 333, 425, 31, 247, 323, 331, 152, 340, 58, 191, 294, 264, 362, 9, 79, 435, 183, 21, 248, 229, 226, 432, 372, 386, 76, 119, 198, 245]
# Всего на профиле 5 50 студентов
# Профиль 6: Студенты - [62, 320, 133, 176, 250, 123, 377, 260, 2, 177, 216, 0, 409, 117, 33, 276, 292, 239, 194, 301, 128, 360, 234, 369, 142, 254, 135, 170, 385, 6, 42, 27, 155, 371, 86, 414, 241, 105, 394, 1, 334, 147, 8, 175, 122, 300, 213, 12, 421, 28, 160, 426, 434, 311, 45, 67, 185, 244, 302, 344, 415, 442]
# Всего на профиле 6 62 студентов
# Профиль 7: Студенты - [48, 315, 289, 365, 352, 20, 395, 266, 291, 85, 270, 396, 407, 136, 427, 278, 61, 437, 448, 223, 212, 121, 70, 10, 189, 35, 262, 159, 273, 72, 137, 327, 68, 306, 408, 98, 280, 296, 46, 228, 91, 141, 436, 17, 63, 411, 49, 11, 303, 5, 441, 258, 364, 143, 406, 26, 171]
# Всего на профиле 7 57 студентов
# Незачисленные студенты:
# []
