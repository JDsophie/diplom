# %%
import random

num_students = 450
num_profiles = 8
min_num_groups = 1
min_group_size = 20
max_group_size = 30
max_num_groups = 5    

students = list(range(num_students))
profiles = list(range(num_profiles))

# Формируем квоты для профилей
quotas = [max_group_size * max_num_groups for _ in range(num_profiles)]

# Генерация меток
student_labels = {
    'is_target': [0] * num_students,
    'is_contract': [0] * num_students,
    'debts': [],
    'rating': []
}

# Генерация меток целевых студентов
num_target_students = int(0.05 * num_students)
target_students = random.sample(students, num_target_students)

for target in target_students:
    student_labels['is_target'][target] = 1

# Генерация меток контрактников
num_contract_students = int(0.3 * num_students)
contract_students = random.sample(students, num_contract_students)

for contract in contract_students:
    student_labels['is_contract'][contract] = 1

# Генерация академических задолженностей
def generate_debts():
    return random.choices(range(8), weights=[10, 5, 3, 3, 2, 2, 1, 1], k=1)[0]

student_labels['debts'] = [generate_debts() for _ in students]

# Генерация баллов рейтинга
student_labels['rating'] = [random.randint(0, 500) for _ in students]

for i in range(num_students):
    print(f"Студент {i}: Целевой - {student_labels['is_target'][i]}, "
          f"Контрактник - {student_labels['is_contract'][i]}, "
          f"Долги - {student_labels['debts'][i]}, "
          f"БРС - {student_labels['rating'][i]}")
# Out:
# Студент 0: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 469
# Студент 1: Целевой - 0, Контрактник - 0, Долги - 6, БРС - 150
# Студент 2: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 98
# Студент 3: Целевой - 0, Контрактник - 1, Долги - 3, БРС - 171
# Студент 4: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 159
# Студент 5: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 436
# Студент 6: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 264
# Студент 7: Целевой - 1, Контрактник - 0, Долги - 5, БРС - 389
# Студент 8: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 270
# Студент 9: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 163
# Студент 10: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 389
# Студент 11: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 330
# Студент 12: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 230
# Студент 13: Целевой - 0, Контрактник - 1, Долги - 2, БРС - 192
# Студент 14: Целевой - 0, Контрактник - 1, Долги - 3, БРС - 255
# Студент 15: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 45
# Студент 16: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 303
# Студент 17: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 366
# Студент 18: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 185
# Студент 19: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 42
# Студент 20: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 427
# Студент 21: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 385
# Студент 22: Целевой - 0, Контрактник - 1, Долги - 5, БРС - 305
# Студент 23: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 211
# Студент 24: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 193
# Студент 25: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 324
# Студент 26: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 293
# Студент 27: Целевой - 0, Контрактник - 1, Долги - 7, БРС - 150
# Студент 28: Целевой - 0, Контрактник - 0, Долги - 6, БРС - 335
# Студент 29: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 197
# Студент 30: Целевой - 0, Контрактник - 1, Долги - 2, БРС - 99
# Студент 31: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 284
# Студент 32: Целевой - 0, Контрактник - 1, Долги - 5, БРС - 387
# Студент 33: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 0
# Студент 34: Целевой - 0, Контрактник - 1, Долги - 6, БРС - 85
# Студент 35: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 497
# Студент 36: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 284
# Студент 37: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 281
# Студент 38: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 329
# Студент 39: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 59
# Студент 40: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 103
# Студент 41: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 288
# Студент 42: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 411
# Студент 43: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 397
# Студент 44: Целевой - 0, Контрактник - 1, Долги - 2, БРС - 263
# Студент 45: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 424
# Студент 46: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 478
# Студент 47: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 265
# Студент 48: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 407
# Студент 49: Целевой - 0, Контрактник - 1, Долги - 4, БРС - 33
# Студент 50: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 336
# Студент 51: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 300
# Студент 52: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 155
# Студент 53: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 25
# Студент 54: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 421
# Студент 55: Целевой - 1, Контрактник - 0, Долги - 2, БРС - 247
# Студент 56: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 450
# Студент 57: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 351
# Студент 58: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 493
# Студент 59: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 412
# Студент 60: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 320
# Студент 61: Целевой - 0, Контрактник - 0, Долги - 7, БРС - 110
# Студент 62: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 451
# Студент 63: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 434
# Студент 64: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 202
# Студент 65: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 349
# Студент 66: Целевой - 1, Контрактник - 0, Долги - 1, БРС - 316
# Студент 67: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 368
# Студент 68: Целевой - 0, Контрактник - 0, Долги - 6, БРС - 25
# Студент 69: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 40
# Студент 70: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 392
# Студент 71: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 231
# Студент 72: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 1
# Студент 73: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 272
# Студент 74: Целевой - 0, Контрактник - 1, Долги - 3, БРС - 57
# Студент 75: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 269
# Студент 76: Целевой - 1, Контрактник - 0, Долги - 1, БРС - 407
# Студент 77: Целевой - 0, Контрактник - 1, Долги - 6, БРС - 71
# Студент 78: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 356
# Студент 79: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 336
# Студент 80: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 355
# Студент 81: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 160
# Студент 82: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 425
# Студент 83: Целевой - 0, Контрактник - 1, Долги - 4, БРС - 428
# Студент 84: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 308
# Студент 85: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 404
# Студент 86: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 55
# Студент 87: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 392
# Студент 88: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 232
# Студент 89: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 167
# Студент 90: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 1
# Студент 91: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 219
# Студент 92: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 455
# Студент 93: Целевой - 0, Контрактник - 1, Долги - 3, БРС - 240
# Студент 94: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 42
# Студент 95: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 146
# Студент 96: Целевой - 0, Контрактник - 0, Долги - 7, БРС - 383
# Студент 97: Целевой - 1, Контрактник - 0, Долги - 0, БРС - 195
# Студент 98: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 486
# Студент 99: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 273
# Студент 100: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 467
# Студент 101: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 283
# Студент 102: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 25
# Студент 103: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 313
# Студент 104: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 372
# Студент 105: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 88
# Студент 106: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 312
# Студент 107: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 441
# Студент 108: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 16
# Студент 109: Целевой - 0, Контрактник - 1, Долги - 3, БРС - 73
# Студент 110: Целевой - 1, Контрактник - 0, Долги - 0, БРС - 60
# Студент 111: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 295
# Студент 112: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 330
# Студент 113: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 325
# Студент 114: Целевой - 0, Контрактник - 1, Долги - 7, БРС - 457
# Студент 115: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 414
# Студент 116: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 118
# Студент 117: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 432
# Студент 118: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 63
# Студент 119: Целевой - 0, Контрактник - 1, Долги - 5, БРС - 267
# Студент 120: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 202
# Студент 121: Целевой - 0, Контрактник - 0, Долги - 6, БРС - 272
# Студент 122: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 434
# Студент 123: Целевой - 0, Контрактник - 1, Долги - 3, БРС - 261
# Студент 124: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 438
# Студент 125: Целевой - 0, Контрактник - 1, Долги - 2, БРС - 139
# Студент 126: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 433
# Студент 127: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 208
# Студент 128: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 274
# Студент 129: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 239
# Студент 130: Целевой - 0, Контрактник - 1, Долги - 3, БРС - 484
# Студент 131: Целевой - 0, Контрактник - 1, Долги - 3, БРС - 337
# Студент 132: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 79
# Студент 133: Целевой - 0, Контрактник - 1, Долги - 2, БРС - 466
# Студент 134: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 69
# Студент 135: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 185
# Студент 136: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 3
# Студент 137: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 419
# Студент 138: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 495
# Студент 139: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 166
# Студент 140: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 380
# Студент 141: Целевой - 0, Контрактник - 1, Долги - 6, БРС - 249
# Студент 142: Целевой - 0, Контрактник - 1, Долги - 3, БРС - 44
# Студент 143: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 35
# Студент 144: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 322
# Студент 145: Целевой - 0, Контрактник - 0, Долги - 6, БРС - 290
# Студент 146: Целевой - 0, Контрактник - 1, Долги - 2, БРС - 83
# Студент 147: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 406
# Студент 148: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 313
# Студент 149: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 188
# Студент 150: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 194
# Студент 151: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 115
# Студент 152: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 167
# Студент 153: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 469
# Студент 154: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 173
# Студент 155: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 220
# Студент 156: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 82
# Студент 157: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 202
# Студент 158: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 185
# Студент 159: Целевой - 0, Контрактник - 0, Долги - 7, БРС - 294
# Студент 160: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 491
# Студент 161: Целевой - 0, Контрактник - 1, Долги - 2, БРС - 33
# Студент 162: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 401
# Студент 163: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 429
# Студент 164: Целевой - 1, Контрактник - 0, Долги - 2, БРС - 155
# Студент 165: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 481
# Студент 166: Целевой - 0, Контрактник - 1, Долги - 2, БРС - 128
# Студент 167: Целевой - 0, Контрактник - 1, Долги - 7, БРС - 458
# Студент 168: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 398
# Студент 169: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 116
# Студент 170: Целевой - 0, Контрактник - 1, Долги - 6, БРС - 417
# Студент 171: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 431
# Студент 172: Целевой - 0, Контрактник - 0, Долги - 7, БРС - 75
# Студент 173: Целевой - 0, Контрактник - 1, Долги - 6, БРС - 486
# Студент 174: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 138
# Студент 175: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 430
# Студент 176: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 423
# Студент 177: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 500
# Студент 178: Целевой - 0, Контрактник - 1, Долги - 4, БРС - 123
# Студент 179: Целевой - 0, Контрактник - 1, Долги - 7, БРС - 152
# Студент 180: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 3
# Студент 181: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 159
# Студент 182: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 222
# Студент 183: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 201
# Студент 184: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 494
# Студент 185: Целевой - 0, Контрактник - 0, Долги - 7, БРС - 320
# Студент 186: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 423
# Студент 187: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 358
# Студент 188: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 8
# Студент 189: Целевой - 0, Контрактник - 0, Долги - 6, БРС - 108
# Студент 190: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 107
# Студент 191: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 207
# Студент 192: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 192
# Студент 193: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 15
# Студент 194: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 464
# Студент 195: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 131
# Студент 196: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 344
# Студент 197: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 444
# Студент 198: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 89
# Студент 199: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 282
# Студент 200: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 346
# Студент 201: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 306
# Студент 202: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 436
# Студент 203: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 16
# Студент 204: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 104
# Студент 205: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 394
# Студент 206: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 136
# Студент 207: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 318
# Студент 208: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 276
# Студент 209: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 18
# Студент 210: Целевой - 1, Контрактник - 0, Долги - 2, БРС - 483
# Студент 211: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 46
# Студент 212: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 29
# Студент 213: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 114
# Студент 214: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 30
# Студент 215: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 149
# Студент 216: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 458
# Студент 217: Целевой - 0, Контрактник - 1, Долги - 2, БРС - 331
# Студент 218: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 2
# Студент 219: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 141
# Студент 220: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 144
# Студент 221: Целевой - 1, Контрактник - 1, Долги - 2, БРС - 499
# Студент 222: Целевой - 0, Контрактник - 1, Долги - 5, БРС - 190
# Студент 223: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 43
# Студент 224: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 261
# Студент 225: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 429
# Студент 226: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 103
# Студент 227: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 260
# Студент 228: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 72
# Студент 229: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 420
# Студент 230: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 180
# Студент 231: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 352
# Студент 232: Целевой - 0, Контрактник - 0, Долги - 7, БРС - 277
# Студент 233: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 109
# Студент 234: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 389
# Студент 235: Целевой - 1, Контрактник - 0, Долги - 0, БРС - 251
# Студент 236: Целевой - 0, Контрактник - 1, Долги - 7, БРС - 272
# Студент 237: Целевой - 1, Контрактник - 0, Долги - 0, БРС - 251
# Студент 238: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 233
# Студент 239: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 93
# Студент 240: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 243
# Студент 241: Целевой - 0, Контрактник - 1, Долги - 2, БРС - 153
# Студент 242: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 138
# Студент 243: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 199
# Студент 244: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 76
# Студент 245: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 304
# Студент 246: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 196
# Студент 247: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 141
# Студент 248: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 64
# Студент 249: Целевой - 1, Контрактник - 0, Долги - 1, БРС - 20
# Студент 250: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 230
# Студент 251: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 286
# Студент 252: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 445
# Студент 253: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 378
# Студент 254: Целевой - 0, Контрактник - 1, Долги - 3, БРС - 433
# Студент 255: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 305
# Студент 256: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 175
# Студент 257: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 326
# Студент 258: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 352
# Студент 259: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 239
# Студент 260: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 254
# Студент 261: Целевой - 0, Контрактник - 1, Долги - 5, БРС - 379
# Студент 262: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 495
# Студент 263: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 189
# Студент 264: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 320
# Студент 265: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 200
# Студент 266: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 201
# Студент 267: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 357
# Студент 268: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 457
# Студент 269: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 90
# Студент 270: Целевой - 0, Контрактник - 1, Долги - 3, БРС - 181
# Студент 271: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 116
# Студент 272: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 131
# Студент 273: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 191
# Студент 274: Целевой - 0, Контрактник - 0, Долги - 7, БРС - 386
# Студент 275: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 129
# Студент 276: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 390
# Студент 277: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 157
# Студент 278: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 362
# Студент 279: Целевой - 0, Контрактник - 1, Долги - 2, БРС - 472
# Студент 280: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 107
# Студент 281: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 41
# Студент 282: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 231
# Студент 283: Целевой - 0, Контрактник - 1, Долги - 4, БРС - 460
# Студент 284: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 41
# Студент 285: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 484
# Студент 286: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 241
# Студент 287: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 18
# Студент 288: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 495
# Студент 289: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 500
# Студент 290: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 361
# Студент 291: Целевой - 1, Контрактник - 1, Долги - 1, БРС - 107
# Студент 292: Целевой - 0, Контрактник - 1, Долги - 6, БРС - 39
# Студент 293: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 316
# Студент 294: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 386
# Студент 295: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 64
# Студент 296: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 485
# Студент 297: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 84
# Студент 298: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 332
# Студент 299: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 6
# Студент 300: Целевой - 0, Контрактник - 0, Долги - 6, БРС - 306
# Студент 301: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 496
# Студент 302: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 206
# Студент 303: Целевой - 1, Контрактник - 0, Долги - 6, БРС - 195
# Студент 304: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 297
# Студент 305: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 401
# Студент 306: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 29
# Студент 307: Целевой - 0, Контрактник - 0, Долги - 7, БРС - 279
# Студент 308: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 406
# Студент 309: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 248
# Студент 310: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 460
# Студент 311: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 188
# Студент 312: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 197
# Студент 313: Целевой - 0, Контрактник - 1, Долги - 3, БРС - 471
# Студент 314: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 367
# Студент 315: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 199
# Студент 316: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 306
# Студент 317: Целевой - 0, Контрактник - 1, Долги - 3, БРС - 260
# Студент 318: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 91
# Студент 319: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 176
# Студент 320: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 416
# Студент 321: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 24
# Студент 322: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 214
# Студент 323: Целевой - 0, Контрактник - 0, Долги - 7, БРС - 308
# Студент 324: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 309
# Студент 325: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 123
# Студент 326: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 479
# Студент 327: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 359
# Студент 328: Целевой - 0, Контрактник - 0, Долги - 7, БРС - 410
# Студент 329: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 245
# Студент 330: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 484
# Студент 331: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 279
# Студент 332: Целевой - 0, Контрактник - 0, Долги - 6, БРС - 172
# Студент 333: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 85
# Студент 334: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 383
# Студент 335: Целевой - 0, Контрактник - 1, Долги - 3, БРС - 178
# Студент 336: Целевой - 1, Контрактник - 0, Долги - 0, БРС - 224
# Студент 337: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 299
# Студент 338: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 227
# Студент 339: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 420
# Студент 340: Целевой - 0, Контрактник - 1, Долги - 6, БРС - 65
# Студент 341: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 311
# Студент 342: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 77
# Студент 343: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 344
# Студент 344: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 175
# Студент 345: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 387
# Студент 346: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 214
# Студент 347: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 255
# Студент 348: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 350
# Студент 349: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 65
# Студент 350: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 234
# Студент 351: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 102
# Студент 352: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 220
# Студент 353: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 290
# Студент 354: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 226
# Студент 355: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 304
# Студент 356: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 3
# Студент 357: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 329
# Студент 358: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 162
# Студент 359: Целевой - 0, Контрактник - 1, Долги - 5, БРС - 329
# Студент 360: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 478
# Студент 361: Целевой - 0, Контрактник - 1, Долги - 7, БРС - 55
# Студент 362: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 34
# Студент 363: Целевой - 0, Контрактник - 1, Долги - 2, БРС - 172
# Студент 364: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 448
# Студент 365: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 29
# Студент 366: Целевой - 0, Контрактник - 0, Долги - 7, БРС - 20
# Студент 367: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 182
# Студент 368: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 490
# Студент 369: Целевой - 1, Контрактник - 0, Долги - 4, БРС - 451
# Студент 370: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 470
# Студент 371: Целевой - 0, Контрактник - 1, Долги - 3, БРС - 233
# Студент 372: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 271
# Студент 373: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 438
# Студент 374: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 188
# Студент 375: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 366
# Студент 376: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 267
# Студент 377: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 136
# Студент 378: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 353
# Студент 379: Целевой - 0, Контрактник - 0, Долги - 7, БРС - 343
# Студент 380: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 247
# Студент 381: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 253
# Студент 382: Целевой - 1, Контрактник - 1, Долги - 4, БРС - 50
# Студент 383: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 213
# Студент 384: Целевой - 1, Контрактник - 1, Долги - 3, БРС - 24
# Студент 385: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 38
# Студент 386: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 330
# Студент 387: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 136
# Студент 388: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 225
# Студент 389: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 306
# Студент 390: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 313
# Студент 391: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 292
# Студент 392: Целевой - 0, Контрактник - 1, Долги - 4, БРС - 48
# Студент 393: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 89
# Студент 394: Целевой - 1, Контрактник - 0, Долги - 1, БРС - 14
# Студент 395: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 393
# Студент 396: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 352
# Студент 397: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 125
# Студент 398: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 11
# Студент 399: Целевой - 0, Контрактник - 1, Долги - 3, БРС - 16
# Студент 400: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 189
# Студент 401: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 470
# Студент 402: Целевой - 1, Контрактник - 0, Долги - 0, БРС - 438
# Студент 403: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 126
# Студент 404: Целевой - 0, Контрактник - 1, Долги - 6, БРС - 155
# Студент 405: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 143
# Студент 406: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 345
# Студент 407: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 335
# Студент 408: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 418
# Студент 409: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 258
# Студент 410: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 333
# Студент 411: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 305
# Студент 412: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 109
# Студент 413: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 334
# Студент 414: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 244
# Студент 415: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 279
# Студент 416: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 354
# Студент 417: Целевой - 0, Контрактник - 1, Долги - 2, БРС - 194
# Студент 418: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 382
# Студент 419: Целевой - 1, Контрактник - 0, Долги - 4, БРС - 198
# Студент 420: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 120
# Студент 421: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 303
# Студент 422: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 107
# Студент 423: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 196
# Студент 424: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 477
# Студент 425: Целевой - 0, Контрактник - 1, Долги - 1, БРС - 437
# Студент 426: Целевой - 1, Контрактник - 0, Долги - 3, БРС - 427
# Студент 427: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 87
# Студент 428: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 169
# Студент 429: Целевой - 0, Контрактник - 1, Долги - 5, БРС - 467
# Студент 430: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 168
# Студент 431: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 426
# Студент 432: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 139
# Студент 433: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 452
# Студент 434: Целевой - 0, Контрактник - 0, Долги - 1, БРС - 335
# Студент 435: Целевой - 0, Контрактник - 1, Долги - 0, БРС - 244
# Студент 436: Целевой - 0, Контрактник - 1, Долги - 5, БРС - 297
# Студент 437: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 347
# Студент 438: Целевой - 0, Контрактник - 0, Долги - 4, БРС - 54
# Студент 439: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 282
# Студент 440: Целевой - 0, Контрактник - 0, Долги - 5, БРС - 61
# Студент 441: Целевой - 0, Контрактник - 1, Долги - 6, БРС - 157
# Студент 442: Целевой - 0, Контрактник - 0, Долги - 0, БРС - 487
# Студент 443: Целевой - 0, Контрактник - 1, Долги - 5, БРС - 88
# Студент 444: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 410
# Студент 445: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 195
# Студент 446: Целевой - 0, Контрактник - 0, Долги - 3, БРС - 446
# Студент 447: Целевой - 0, Контрактник - 0, Долги - 2, БРС - 97
# Студент 448: Целевой - 0, Контрактник - 0, Долги - 7, БРС - 299
# Студент 449: Целевой - 0, Контрактник - 1, Долги - 3, БРС - 284

# %%
# Генерация предпочтений студентов
preferences_s = {}
for student in students:
    if student_labels['debts'][student] > 5:
        preferences_s[student] = []  # Равнодушие к профилям, пустой список
    else:
        preferences_s[student] = random.sample(profiles, k=num_profiles)  # Выбор профилей

# Генерация предпочтений профилей
preferences_p = {}
for prof in profiles:
    target_students_sorted = sorted(
        [s for s in students if student_labels['is_target'][s] == 1],
        key=lambda s: -student_labels['rating'][s]
    )

    other_students = sorted(
        [s for s in students if student_labels['is_target'][s] == 0 and student_labels['debts'][s] <= 5],
        key=lambda s: (-student_labels['rating'][s], -student_labels['is_contract'][s])
    )

    debt_students = sorted(
        [s for s in students if student_labels['debts'][s] > 5],
        key=lambda s: -student_labels['rating'][s]
    )

    # Формируем полные предпочтения для профиля
    preferences_p[prof] = target_students_sorted + other_students + debt_students

# Подсчет студентов, которые поставили профиль первым приоритетом
priority_count = {prof: 0 for prof in profiles}
target_priority_count = {prof: 0 for prof in profiles}

for student in students:
    if preferences_s[student]:  # Проверяем, есть ли предпочтения
        first_preference = preferences_s[student][0]
        priority_count[first_preference] += 1  # Увеличиваем счетчик для данного профиля

        if student_labels['is_target'][student] == 1 and first_preference == preferences_s[student][0]:
            target_priority_count[first_preference] += 1  # Увеличиваем счетчик целевых студентов

# Определение обязательных профилей
mandatory_profiles = [
    prof for prof in profiles 
    if target_priority_count[prof] > 4 or priority_count[prof] > 60
]

# Количество обязательных профилей
num_mandatory_profiles = len(mandatory_profiles)

# Объем резерва
reserve_size = num_mandatory_profiles * min_num_groups * min_group_size
reserve_students = []

# Список студентов без предпочтений
students_without_preferences = []
for student in students:
    if not preferences_s[student]:
        students_without_preferences.append(student)

# Список оставшихся нецелевых студентов
remaining_students = []
for student in students:
    if student_labels['is_target'][student] == 0:
        remaining_students.append(student)

# Заполнение резерва студентами без предпочтений
students_without_preferences_sorted = sorted(
    students_without_preferences, 
    key=lambda s: student_labels['rating'][s]
)

for student in reversed(students_without_preferences_sorted):
    if len(reserve_students) < reserve_size:
        reserve_students.append(student)
    else:
        break

# Заполнение резерва оставшимися нецелевыми студентами
remaining_students_sorted = sorted(
    remaining_students,
    key=lambda s: student_labels['rating'][s]
)

for student in reversed(remaining_students_sorted):
    if len(reserve_students) < reserve_size:
        reserve_students.append(student)
    else:
        break

# Вывод результатов
for prof in profiles:
    print(f"Профиль {prof}: Студенты, поставившие первым приоритетом: {priority_count[prof]}, "
          f"целевиков: {target_priority_count[prof]}")

print(f"Размер резерва студентов: {len(reserve_students)}")
print(f"Резерв студентов: {reserve_students}")
# Out:
# Профиль 0: Студенты, поставившие первым приоритетом: 49, целевиков: 2
# Профиль 1: Студенты, поставившие первым приоритетом: 52, целевиков: 2
# Профиль 2: Студенты, поставившие первым приоритетом: 53, целевиков: 4
# Профиль 3: Студенты, поставившие первым приоритетом: 52, целевиков: 3
# Профиль 4: Студенты, поставившие первым приоритетом: 56, целевиков: 8
# Профиль 5: Студенты, поставившие первым приоритетом: 57, целевиков: 1
# Профиль 6: Студенты, поставившие первым приоритетом: 48, целевиков: 1
# Профиль 7: Студенты, поставившие первым приоритетом: 46, целевиков: 0
# Размер резерва студентов: 20
# Резерв студентов: [173, 167, 114, 170, 328, 274, 96, 379, 28, 185, 323, 300, 448, 159, 145, 307, 232, 236, 121, 141]

# %%
def gale_shapley(num_students, num_profiles, quotas, preferences_s, preferences_p, mandatory_profiles, reserve_students):
    # Инициализация
    profiles_matches = {prof: [] for prof in range(num_profiles)}  # Сопоставления профилей
    student_matches = {student: None for student in range(num_students)}  # Сопоставления студентов
    reserve_set = set(reserve_students)  # Студенты в резерве
    # Убираем студентов из резерва из remaining_students_after_distribution
    free_students = [s for s in students if s not in reserve_set]  
    proposed = {student: 0 for student in range(num_students)}  # Счетчик предложений

    while free_students:
        # Вытаскиваем свободного студента
        student = free_students[0]
        student_pref = preferences_s[student]

        # Находим наиболее предпочтительный профиль, которому студент еще не делал предложение
        prof_index = proposed[student]

        if prof_index < len(student_pref):  # Здесь используем длину предпочтений, чтобы не сломаться на студентах с пустыми списками
            prof = student_pref[prof_index]
            proposed[student] += 1

            # Если профиль свободен, совмещаем
            if len(profiles_matches[prof]) < quotas[prof]:
                profiles_matches[prof].append(student)
                profiles_matches[prof].sort(key=preferences_p[prof].index)
                student_matches[student] = prof
                free_students.pop(0)

                # Проверяем с обязательным профилем и обрабатываем резерв
                if prof in mandatory_profiles and reserve_students:
                    student_from_reserve = reserve_students.pop(0)  # Берем первого студента из резерва
                    free_students.append(student_from_reserve)  # Добавляем студента в список свободных
            else:
                # Если профиль занят, проверяем, хочет ли он заменить текущего худшего студента
                current_student = profiles_matches[prof][-1]
                prof_pref = preferences_p[prof]

                if prof_pref.index(student) < prof_pref.index(current_student):
                    profiles_matches[prof].pop()
                    profiles_matches[prof].append(student)
                    profiles_matches[prof].sort(key=prof_pref.index)
                    student_matches[student] = prof
                    student_matches[current_student] = None
                    free_students.pop(0)
                    free_students.append(current_student)

                    # Проверяем с обязательным профилем и обрабатываем резерв
                    if prof in mandatory_profiles and reserve_students:
                        student_from_reserve = reserve_students.pop(0)  # Берем первого студента из резерва
                        free_students.append(student_from_reserve)  # Добавляем студента во свободные списки
        else:
            # Если студент сделал все предложения, он становится несопоставленным
            free_students.pop(0)

    # Список студентов с пустыми предпочтениями
    students_with_no_preferences = [s for s in range(num_students) if len(preferences_s[s]) == 0]
    # Основной цикл распределения завершен

    # Теперь распределяем студентов с пустыми предпочтениями случайным образом
    for student in students_with_no_preferences:
        available_profiles = [prof for prof in range(num_profiles) if len(profiles_matches[prof]) < quotas[prof]]
        if available_profiles:  # Если есть доступные профили
            prof = random.choice(available_profiles)  # Случайный профиль
            profiles_matches[prof].append(student)  # Записываем студента на профиль
            student_matches[student] = prof  # Обновляем сопоставление студента

    # Список несопоставленных студентов
    unmatched_students = [s for s in range(num_students) if student_matches[s] is None]

    return profiles_matches, student_matches, unmatched_students

# %%
profiles_matches, student_matches, unmatched_students = gale_shapley(
    num_students, num_profiles, quotas, preferences_s, preferences_p, mandatory_profiles, reserve_students
)

for prof, matched_students in profiles_matches.items():
    print(f"Профиль {prof}: Студенты - {matched_students}")
    print(f"Всего на профиле {prof} {len(matched_students)} студентов")

print("Незачисленные студенты:")
print(unmatched_students)
# Out:
# Профиль 0: Студенты - [382, 249, 177, 98, 330, 360, 0, 62, 446, 107, 373, 339, 334, 140, 290, 396, 348, 207, 103, 355, 51, 436, 101, 128, 376, 381, 286, 71, 352, 302, 192, 18, 256, 358, 215, 125, 412, 109, 134, 248, 118, 86, 392, 19, 94, 203, 398, 218, 72, 1, 96, 323]
# Всего на профиле 0 52 студентов
# Профиль 1: Студенты - [164, 394, 368, 442, 130, 46, 153, 310, 433, 425, 83, 54, 42, 43, 258, 65, 50, 434, 359, 144, 106, 22, 26, 391, 415, 73, 44, 414, 282, 338, 127, 265, 315, 246, 400, 335, 154, 89, 9, 181, 52, 432, 387, 206, 195, 233, 30, 447, 318, 39, 15, 284, 61, 145, 189, 361, 366]
# Всего на профиле 1 57 студентов
# Профиль 2: Студенты - [221, 76, 291, 110, 35, 301, 262, 175, 82, 45, 408, 59, 147, 168, 395, 21, 67, 17, 378, 57, 407, 257, 113, 25, 201, 255, 245, 224, 317, 309, 329, 129, 371, 243, 423, 24, 13, 430, 81, 241, 174, 242, 272, 420, 204, 226, 269, 143, 362, 214, 108, 180, 33, 68, 172, 236, 340, 404, 448]
# Всего на профиле 2 59 студентов
# Профиль 3: Студенты - [7, 235, 419, 289, 184, 424, 313, 370, 401, 283, 216, 5, 126, 431, 229, 70, 10, 78, 231, 264, 148, 411, 421, 304, 111, 199, 208, 8, 119, 47, 123, 347, 259, 350, 88, 155, 91, 120, 157, 445, 417, 230, 319, 363, 3, 403, 351, 443, 342, 349, 161, 53, 28, 441]
# Всего на профиле 3 54 студентов
# Профиль 4: Студенты - [402, 426, 66, 237, 55, 336, 97, 384, 288, 285, 326, 279, 56, 197, 122, 117, 225, 261, 314, 187, 343, 38, 390, 324, 84, 389, 353, 449, 439, 99, 372, 240, 93, 312, 273, 367, 428, 95, 219, 377, 271, 213, 422, 40, 105, 146, 132, 438, 142, 223, 385, 212, 287, 399, 299, 356, 114, 121, 232, 292, 379]
# Всего на профиле 4 61 студентов
# Профиль 5: Студенты - [369, 138, 58, 160, 429, 133, 268, 124, 171, 163, 20, 176, 137, 320, 115, 48, 205, 345, 104, 278, 200, 410, 298, 112, 357, 60, 293, 16, 331, 409, 260, 380, 435, 238, 346, 322, 383, 222, 149, 152, 139, 4, 277, 405, 166, 325, 280, 2, 333, 297, 156, 211, 306, 365, 102, 321, 136, 27, 170, 179, 300, 307]
# Всего на профиле 5 62 студентов
# Профиль 6: Студенты - [210, 296, 92, 364, 202, 254, 186, 85, 162, 276, 32, 294, 418, 267, 416, 437, 406, 196, 131, 79, 413, 217, 386, 316, 337, 31, 36, 37, 6, 14, 12, 354, 64, 266, 374, 270, 397, 178, 116, 198, 393, 427, 440, 74, 281, 49, 188, 90, 77, 159, 173, 303]
# Всего на профиле 6 52 студентов
# Профиль 7: Студенты - [165, 100, 194, 252, 63, 444, 308, 305, 87, 234, 253, 375, 327, 80, 11, 341, 41, 251, 75, 227, 250, 388, 182, 23, 191, 183, 29, 150, 263, 311, 135, 158, 344, 220, 247, 275, 169, 151, 190, 239, 244, 228, 295, 69, 209, 193, 34, 141, 167, 185, 274, 328, 332]
# Всего на профиле 7 53 студентов
# Незачисленные студенты:
# []
